# %% [markdown]
# # Import Necessary Libraries

# %%
# Install missing packages
# %pip install numpy pandas matplotlib seaborn scikit-learn

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
# Out:
# Requirement already satisfied: numpy in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.5)
# Requirement already satisfied: pandas in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\21200\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\21200\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Provide the full path to the file
df = pd.read_csv(r"C:\Users\21200\Downloads\SPAM-SMS-DETECTION-main\SPAM-SMS-DETECTION-main\Datasets\spam_data.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Provide the full path to the file
# ----> 2 df = pd.read_csv(r"C:\Users\21200\Downloads\SPAM-SMS-DETECTION-main\SPAM-SMS-DETECTION-main\Datasets\spam_data.csv")
#       3 df.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\21200\\Downloads\\SPAM-SMS-DETECTION-main\\SPAM-SMS-DETECTION-main\\Datasets\\spam_data.csv'

# %%
# Ensure df is defined and contains the correct data
# Ensure df is defined and contains the correct data
if 'df' in globals():
	df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1, inplace=True)
	print(df.shape)
else:
	print("Error: 'df' is not defined. Please ensure CELL INDEX 2 is executed.")
# Out:
# Error: 'df' is not defined. Please ensure CELL INDEX 2 is executed.

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Checking for Missing Values

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Check for missing values
# ----> 2 print(df.isnull().sum())
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Distribution of Spam vs. Ham Messages

# %%
# Countplot for spam vs. ham messages
sns.countplot(data=df, x='type')
plt.title('Distribution of Spam vs. Ham Messages')
plt.xlabel('Message Type')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Countplot for spam vs. ham messages
# ----> 2 sns.countplot(data=df, x='type')
#       3 plt.title('Distribution of Spam vs. Ham Messages')
#       4 plt.xlabel('Message Type')
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Splitting the data into features and target variable

# %%
X = df['message']
y = df['type']

# %%
X
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                Will �_ b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: message, Length: 5572, dtype: object

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 y
#
# NameError: name 'y' is not defined

# %% [markdown]
# # TF-IDF Vectorization

# %%
#For the machine learning models, we'll need to preprocess the text data by converting it into numerical features. 
#This can be done using techniques like TF-IDF (Term Frequency-Inverse Document Frequency).
tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(X)

# %% [markdown]
# # Splitting into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)
#
# NameError: name 'X_tfidf' is not defined

# %% [markdown]
# # Logistic Regression

# %%
logistic_regression = LogisticRegression(max_iter=1000)

# %%
# Training the models
logistic_regression.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Prediction
logistic_regression_pred = logistic_regression.predict(X_test)

# %%
# Evaluation
logistic_regression_accuracy = accuracy_score(y_test, logistic_regression_pred)

# %%
# Print accuracies
print(f"Logistic Regression Accuracy: {logistic_regression_accuracy}")
# Out:
# Logistic Regression Accuracy: 0.9614349775784753

# %% [markdown]
# # Support Vector Machines

# %%
svm = SVC()

# %%
# Training the models
svm.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Training the models
# ----> 2 svm.fit(X_train, y_train)
#
# NameError: name 'svm' is not defined

# %%
# Prediction
svm_pred = svm.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Prediction
# ----> 2 svm_pred = svm.predict(X_test)
#
# NameError: name 'svm' is not defined

# %%
svm_accuracy = accuracy_score(y_test, svm_pred)

# %%
print(f"SVM Accuracy: {svm_accuracy}")
# Out:
# SVM Accuracy: 0.9757847533632287

# %% [markdown]
# # Naive Bayes

# %%
naive_bayes = MultinomialNB()

# %%
# Training the models
naive_bayes.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# Prediction
naive_bayes_pred = naive_bayes.predict(X_test)

# %%
naive_bayes_accuracy = accuracy_score(y_test, naive_bayes_pred)

# %%
print(f"Naive Bayes Accuracy: {naive_bayes_accuracy}")
# Out:
# Naive Bayes Accuracy: 0.9623318385650225

# %% [markdown]
# # Find the best model

# %%
best_model = max(logistic_regression_accuracy, svm_accuracy, naive_bayes_accuracy)

if best_model == logistic_regression_accuracy:
    print("Logistic Regression performs the best.")
elif best_model == svm_accuracy:
    print("SVM performs the best.")
else:
    print("Naive Bayes performs the best.")
# Out:
# SVM performs the best.

# %% [markdown]
# # Saving Model as .pkl file

# %%
import pickle
pickle.dump(svm,open('finalized_model.pkl','wb'))

# %%
pickle.dump(tfidf, open('vectorizor.pkl','wb'))
